# %% [markdown]
# <a href="https://colab.research.google.com/github/Swathi0313/CSEP/blob/main/21-06-2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from matplotlib import pyplot as plt
x=np.linspace(-np.pi,np.pi,100)
y=np.sin(x)
my_file=open('sin_data.txt','w')
my_file.write('#This is my sine function.\n')
for i in range(len(x)):
  my_file.write("%f \t %f \n"%(x[i],y[i]))
my_file.close()
data=np.loadtxt("sin_data.txt")
#print(data)
#print(data[:,0])#prints x values
#print(data[:,1])#prints y values
print("binary#################")
data_array=np.vstack((x,y))
np.save('sin_data_bin',data_array)
data_bin=np.load('din_data_bin.npy')
print(data_bin)
print("h5##########################")
write_file=h5py.File('abc.h5','w')
write_file['data_1']=data_array
write_file.colse()
read_file=h5py.File('abc.h5')
z=read_file['data_1']
z=np.array(z)
read_file.close()
# Out:
# [[-3.141593 -0.      ]
#  [-3.078126 -0.063424]
#  [-3.01466  -0.126592]
#  [-2.951193 -0.189251]
#  [-2.887727 -0.251148]
#  [-2.82426  -0.312033]
#  [-2.760794 -0.371662]
#  [-2.697327 -0.429795]
#  [-2.633861 -0.486197]
#  [-2.570394 -0.540641]
#  [-2.506927 -0.592908]
#  [-2.443461 -0.642788]
#  [-2.379994 -0.690079]
#  [-2.316528 -0.734592]
#  [-2.253061 -0.776146]
#  [-2.189595 -0.814576]
#  [-2.126128 -0.849725]
#  [-2.062662 -0.881453]
#  [-1.999195 -0.909632]
#  [-1.935729 -0.934148]
#  [-1.872262 -0.954902]
#  [-1.808796 -0.971812]
#  [-1.745329 -0.984808]
#  [-1.681863 -0.993838]
#  [-1.618396 -0.998867]
#  [-1.55493  -0.999874]
#  [-1.491463 -0.996855]
#  [-1.427997 -0.989821]
#  [-1.36453  -0.978802]
#  [-1.301064 -0.963842]
#  [-1.237597 -0.945001]
#  [-1.174131 -0.922354]
#  [-1.110664 -0.895994]
#  [-1.047198 -0.866025]
#  [-0.983731 -0.83257 ]
#  [-0.920265 -0.795762]
#  [-0.856798 -0.75575 ]
#  [-0.793331 -0.712694]
#  [-0.729865 -0.666769]
#  [-0.666398 -0.618159]
# ...
